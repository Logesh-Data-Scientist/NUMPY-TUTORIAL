# %% [markdown]
# SALARY DATA ANALYSIS USING NUMPY
#
# generate random salary data and compute stats

# %%
import numpy as np
np.random.seed(0)
salaries = np.random.randint(20000,100000,size=1000)
print("Salaries: ", np.ceil(salaries))
print("Average salary\t\t\t: ", np.mean(salaries))
print("Median salary\t\t\t: ", np.median(salaries))
print("Salary standard deviation\t: ", np.std(salaries))
print("highest salary\t\t\t: ", np.max(salaries))
print("Lowest salary\t\t\t: ", np.min(salaries))
# Out:
# Salaries:  [88268 63567 62613 65891 41243 61993 75026 68600 59512 72620 37089 52230
#  38983 26921 58804 87699 90608 57619 27877 21871 93135 22496 67954 44675
#  51921 20797 69811 88755 72489 61504 69866 31723 63890 37591 78146 79300
#  91557 40006 23560 81713 65444 66522 40737 48647 81353 32134 80535 67883
#  83360 71811 29781 39340 47257 36298 32372 24420 82079 99860 27012 29396
#  23918 29359 64259 43482 35127 57237 99701 28752 91331 70624 60133 75153
#  82756 68682 86509 95751 96693 44777 33824 22418 32843 98778 56223 81570
#  26521 76894 94659 34254 71939 57073 43310 51785 84570 76356 43306 56950
#  98696 98928 99904 90838 53920 99128 53538 28286 38728 33640 88627 65663
#  23912 70586 92130 41752 79715 27997 73006 60800 35620 90381 74268 89069
#  88473 62512 39608 90557 37340 21913 72086 33429 33907 55489 30088 35588
#  58395 80155 58214 20469 63295 94253 54488 58040 36975 35912 48086 35115
#  99983 72573 84223 31052 35741 77368 63986 25103 55050 21740 75270 32579
# ...
